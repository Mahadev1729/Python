# %%
import matplotlib.pyplot as plt 
# x=['A','B','C','D','E']
values=[23,13,4,56,7]

plt.hist(values,bins=3,color='orange',edgecolor='black')
# Out:
# (array([3., 1., 1.]),
#  array([ 4.        , 21.33333333, 38.66666667, 56.        ]),
#  <BarContainer object of 3 artists>)
