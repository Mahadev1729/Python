# %%
import matplotlib.pyplot as plt 
# x=['A','B','C','D','E']
values=[23,13,4,56,7,67,8,9,0]

plt.hist(values,bins=5,color='orange',edgecolor='black')
# Out:
# (array([6., 1., 0., 0., 2.]),
#  array([ 0. , 13.4, 26.8, 40.2, 53.6, 67. ]),
#  <BarContainer object of 5 artists>)
