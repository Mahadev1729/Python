# %%
# 5 number summary and box plot

import numpy as np

lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
minum,Q1,meadian,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.5,0.75,1.0])

minum,Q1,meadian,Q3,maximum

IQR=Q3-Q1
IQR

lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)

IQR,lower_fence,higher_fence
# Out:
# (35.0, 1.5, 141.5)

# %%
#creating box plot
import seaborn as sns
sns.boxplot(lst_marks)
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]

# %%
lst_marks=[-100,-200,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,180]
sns.boxplot(lst_marks)
# Out:
# <Axes: >
