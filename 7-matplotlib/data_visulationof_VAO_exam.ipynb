# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('data_result.csv')
x=list(df['Candidate Name'])
y=list(df['total '])
plt.bar(x,y,color='red')
plt.title("Result")
plt.ylabel('Marks')
plt.xlabel('Candidate Name')
plt.show()
