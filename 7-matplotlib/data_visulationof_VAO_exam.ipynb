# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('data_result.csv')
x=list(df['Candidate Name'])
y=list(df['total '])
plt.bar(y,x,color='red')
plt.title("Result")
plt.pie(y,labels=x)
# plt.ylabel('Marks')
# plt.xlabel('Candidate Name')
# plt.hist(y,bins=3,color='green',edgecolor='black')
# plt.savefig('vis.pdf',bbox_inches='tight')
# Out:
# ([<matplotlib.patches.Wedge at 0x1bd88474290>,
#   <matplotlib.patches.Wedge at 0x1bd8a9577a0>,
#   <matplotlib.patches.Wedge at 0x1bd84bbeb10>,
#   <matplotlib.patches.Wedge at 0x1bd84816510>,
#   <matplotlib.patches.Wedge at 0x1bd84b62e10>,
#   <matplotlib.patches.Wedge at 0x1bd8d001ca0>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f45f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f4a40>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f4e30>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f5220>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f55b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f59d0>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f5df0>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f61b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f65d0>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f69f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f6e70>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f7170>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f76b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f7b00>,
#   <matplotlib.patches.Wedge at 0x1bd8d0f7dd0>,
#   <matplotlib.patches.Wedge at 0x1bd8d144230>,
#   <matplotlib.patches.Wedge at 0x1bd8d144770>,
#   <matplotlib.patches.Wedge at 0x1bd8d144bc0>,
#   <matplotlib.patches.Wedge at 0x1bd8d144f80>,
#   <matplotlib.patches.Wedge at 0x1bd8d1453d0>,
#   <matplotlib.patches.Wedge at 0x1bd8d1457c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d145c10>,
#   <matplotlib.patches.Wedge at 0x1bd8d146030>,
#   <matplotlib.patches.Wedge at 0x1bd8d146480>,
#   <matplotlib.patches.Wedge at 0x1bd8d146870>,
#   <matplotlib.patches.Wedge at 0x1bd8d146c90>,
#   <matplotlib.patches.Wedge at 0x1bd8d1470b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d147530>,
#   <matplotlib.patches.Wedge at 0x1bd8d1479b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d147da0>,
#   <matplotlib.patches.Wedge at 0x1bd8d17c230>,
#   <matplotlib.patches.Wedge at 0x1bd8d17c5f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d17ca40>,
#   <matplotlib.patches.Wedge at 0x1bd8d17ce90>,
#   <matplotlib.patches.Wedge at 0x1bd8d17d310>,
#   <matplotlib.patches.Wedge at 0x1bd8d17d700>,
#   <matplotlib.patches.Wedge at 0x1bd8d17daf0>,
#   <matplotlib.patches.Wedge at 0x1bd8d17dee0>,
#   <matplotlib.patches.Wedge at 0x1bd8d17e360>,
#   <matplotlib.patches.Wedge at 0x1bd8d17e7b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d17ebd0>,
#   <matplotlib.patches.Wedge at 0x1bd8d17eff0>,
#   <matplotlib.patches.Wedge at 0x1bd8d17f3e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d17f800>,
#   <matplotlib.patches.Wedge at 0x1bd8d17fc50>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bc050>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bc590>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bc890>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bcdd0>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bd220>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bd6a0>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bdaf0>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bdeb0>,
#   <matplotlib.patches.Wedge at 0x1bd8d1be300>,
#   <matplotlib.patches.Wedge at 0x1bd8d1be750>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bebd0>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bf020>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bf470>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bf860>,
#   <matplotlib.patches.Wedge at 0x1bd8d1bfce0>,
#   <matplotlib.patches.Wedge at 0x1bd8d1e8170>,
#   <matplotlib.patches.Wedge at 0x1bd8d1e8560>,
#   <matplotlib.patches.Wedge at 0x1bd8d1e89b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d1e8dd0>,
#   <matplotlib.patches.Wedge at 0x1bd8d1e9220>,
#   <matplotlib.patches.Wedge at 0x1bd8d1e9640>,
#   <matplotlib.patches.Wedge at 0x1bd8d1e9a00>,
#   <matplotlib.patches.Wedge at 0x1bd8d1e9e50>,
#   <matplotlib.patches.Wedge at 0x1bd8d1ea2d0>,
#   <matplotlib.patches.Wedge at 0x1bd8d1ea750>,
#   <matplotlib.patches.Wedge at 0x1bd8d1eabd0>,
#   <matplotlib.patches.Wedge at 0x1bd8d1eb050>,
#   <matplotlib.patches.Wedge at 0x1bd8d1eb320>,
#   <matplotlib.patches.Wedge at 0x1bd8d1eb8f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d1ebd40>,
#   <matplotlib.patches.Wedge at 0x1bd8d2281d0>,
#   <matplotlib.patches.Wedge at 0x1bd8d228530>,
#   <matplotlib.patches.Wedge at 0x1bd8d228980>,
#   <matplotlib.patches.Wedge at 0x1bd8d228dd0>,
#   <matplotlib.patches.Wedge at 0x1bd8d2291f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d229640>,
#   <matplotlib.patches.Wedge at 0x1bd8d229910>,
#   <matplotlib.patches.Wedge at 0x1bd8d229e50>,
#   <matplotlib.patches.Wedge at 0x1bd8d22a2d0>,
#   <matplotlib.patches.Wedge at 0x1bd8d22a600>,
#   <matplotlib.patches.Wedge at 0x1bd8d22aba0>,
#   <matplotlib.patches.Wedge at 0x1bd8d22b050>,
#   <matplotlib.patches.Wedge at 0x1bd8d22b500>,
#   <matplotlib.patches.Wedge at 0x1bd8d22b9b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d22be00>,
#   <matplotlib.patches.Wedge at 0x1bd8d260200>,
#   <matplotlib.patches.Wedge at 0x1bd8d2605f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d2609e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d260e60>,
#   <matplotlib.patches.Wedge at 0x1bd8d261280>,
#   <matplotlib.patches.Wedge at 0x1bd8d261670>,
#   <matplotlib.patches.Wedge at 0x1bd8d2619a0>,
#   <matplotlib.patches.Wedge at 0x1bd8d261ee0>,
#   <matplotlib.patches.Wedge at 0x1bd8d262360>,
#   <matplotlib.patches.Wedge at 0x1bd8d2627e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d262c60>,
#   <matplotlib.patches.Wedge at 0x1bd8d2630b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d263530>,
#   <matplotlib.patches.Wedge at 0x1bd8d2639e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d263e30>,
#   <matplotlib.patches.Wedge at 0x1bd8d298170>,
#   <matplotlib.patches.Wedge at 0x1bd8d2986e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d298b30>,
#   <matplotlib.patches.Wedge at 0x1bd8d298f80>,
#   <matplotlib.patches.Wedge at 0x1bd8d299400>,
#   <matplotlib.patches.Wedge at 0x1bd8d299820>,
#   <matplotlib.patches.Wedge at 0x1bd8d299c70>,
#   <matplotlib.patches.Wedge at 0x1bd8d29a060>,
#   <matplotlib.patches.Wedge at 0x1bd8d29a4e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d29a960>,
#   <matplotlib.patches.Wedge at 0x1bd8d29adb0>,
#   <matplotlib.patches.Wedge at 0x1bd8d29b230>,
#   <matplotlib.patches.Wedge at 0x1bd8d29b6b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d29bb00>,
#   <matplotlib.patches.Wedge at 0x1bd8d29bf80>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d0410>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d08f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d0d40>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d1190>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d15e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d1a30>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d1df0>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d20c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d2690>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d2ae0>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d2f30>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d3230>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d37a0>,
#   <matplotlib.patches.Wedge at 0x1bd8d2d3bf0>,
#   <matplotlib.patches.Wedge at 0x1bd8d308050>,
#   <matplotlib.patches.Wedge at 0x1bd8d3084d0>,
#   <matplotlib.patches.Wedge at 0x1bd8d308920>,
#   <matplotlib.patches.Wedge at 0x1bd8d308bf0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3091c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d309640>,
#   <matplotlib.patches.Wedge at 0x1bd8d309a90>,
#   <matplotlib.patches.Wedge at 0x1bd8d309f40>,
#   <matplotlib.patches.Wedge at 0x1bd8d30a3c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d30a840>,
#   <matplotlib.patches.Wedge at 0x1bd8d30ac90>,
#   <matplotlib.patches.Wedge at 0x1bd8d30b110>,
#   <matplotlib.patches.Wedge at 0x1bd8d30b530>,
#   <matplotlib.patches.Wedge at 0x1bd8d30b980>,
#   <matplotlib.patches.Wedge at 0x1bd8d30be00>,
#   <matplotlib.patches.Wedge at 0x1bd8d3402c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3406e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d340b60>,
#   <matplotlib.patches.Wedge at 0x1bd8d341040>,
#   <matplotlib.patches.Wedge at 0x1bd8d341490>,
#   <matplotlib.patches.Wedge at 0x1bd8d341940>,
#   <matplotlib.patches.Wedge at 0x1bd8d341d90>,
#   <matplotlib.patches.Wedge at 0x1bd8d342240>,
#   <matplotlib.patches.Wedge at 0x1bd8d342660>,
#   <matplotlib.patches.Wedge at 0x1bd8d342ab0>,
#   <matplotlib.patches.Wedge at 0x1bd8d342d80>,
#   <matplotlib.patches.Wedge at 0x1bd8d343320>,
#   <matplotlib.patches.Wedge at 0x1bd8d343770>,
#   <matplotlib.patches.Wedge at 0x1bd8d343b60>,
#   <matplotlib.patches.Wedge at 0x1bd8d343fe0>,
#   <matplotlib.patches.Wedge at 0x1bd8d374470>,
#   <matplotlib.patches.Wedge at 0x1bd8d3748f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d374d70>,
#   <matplotlib.patches.Wedge at 0x1bd8d3751c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3755e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d375a30>,
#   <matplotlib.patches.Wedge at 0x1bd8d375e80>,
#   <matplotlib.patches.Wedge at 0x1bd8d3762d0>,
#   <matplotlib.patches.Wedge at 0x1bd8d376720>,
#   <matplotlib.patches.Wedge at 0x1bd8d376ba0>,
#   <matplotlib.patches.Wedge at 0x1bd8d376ea0>,
#   <matplotlib.patches.Wedge at 0x1bd8d377440>,
#   <matplotlib.patches.Wedge at 0x1bd8d3778c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d377d40>,
#   <matplotlib.patches.Wedge at 0x1bd8d3a8200>,
#   <matplotlib.patches.Wedge at 0x1bd8d3a8680>,
#   <matplotlib.patches.Wedge at 0x1bd8d3a8ad0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3a8ef0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3a9340>,
#   <matplotlib.patches.Wedge at 0x1bd8d3a9790>,
#   <matplotlib.patches.Wedge at 0x1bd8d3a9c40>,
#   <matplotlib.patches.Wedge at 0x1bd8d3aa0c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3aa510>,
#   <matplotlib.patches.Wedge at 0x1bd8d3aa930>,
#   <matplotlib.patches.Wedge at 0x1bd8d3aade0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3ab260>,
#   <matplotlib.patches.Wedge at 0x1bd8d3ab6b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3abb30>,
#   <matplotlib.patches.Wedge at 0x1bd8d3abf50>,
#   <matplotlib.patches.Wedge at 0x1bd8d3dc440>,
#   <matplotlib.patches.Wedge at 0x1bd8d3dc830>,
#   <matplotlib.patches.Wedge at 0x1bd8d3dccb0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3dd0d0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3dd4f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3dd970>,
#   <matplotlib.patches.Wedge at 0x1bd8d3dddc0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3de1e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d3de600>,
#   <matplotlib.patches.Wedge at 0x1bd8d3dea80>,
#   <matplotlib.patches.Wedge at 0x1bd8d3def00>,
#   <matplotlib.patches.Wedge at 0x1bd8d3df380>,
#   <matplotlib.patches.Wedge at 0x1bd8d3df800>,
#   <matplotlib.patches.Wedge at 0x1bd8d3dfc80>,
#   <matplotlib.patches.Wedge at 0x1bd8d418140>,
#   <matplotlib.patches.Wedge at 0x1bd8d4185c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d418a10>,
#   <matplotlib.patches.Wedge at 0x1bd8d418e00>,
#   <matplotlib.patches.Wedge at 0x1bd8d419250>,
#   <matplotlib.patches.Wedge at 0x1bd8d419670>,
#   <matplotlib.patches.Wedge at 0x1bd8d419af0>,
#   <matplotlib.patches.Wedge at 0x1bd8d419f70>,
#   <matplotlib.patches.Wedge at 0x1bd8d41a3c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d41a840>,
#   <matplotlib.patches.Wedge at 0x1bd8d41acc0>,
#   <matplotlib.patches.Wedge at 0x1bd8d41aff0>,
#   <matplotlib.patches.Wedge at 0x1bd8d41b3e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d41b9e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d41be30>,
#   <matplotlib.patches.Wedge at 0x1bd8d44c290>,
#   <matplotlib.patches.Wedge at 0x1bd8d44c740>,
#   <matplotlib.patches.Wedge at 0x1bd8d44cbc0>,
#   <matplotlib.patches.Wedge at 0x1bd8d44d040>,
#   <matplotlib.patches.Wedge at 0x1bd8d44d4f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d44d910>,
#   <matplotlib.patches.Wedge at 0x1bd8d44dd60>,
#   <matplotlib.patches.Wedge at 0x1bd8d44e1e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d44e600>,
#   <matplotlib.patches.Wedge at 0x1bd8d44e9f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d44ee40>,
#   <matplotlib.patches.Wedge at 0x1bd8d44f2c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d44f770>,
#   <matplotlib.patches.Wedge at 0x1bd8d44fc50>,
#   <matplotlib.patches.Wedge at 0x1bd8d4800e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d480500>,
#   <matplotlib.patches.Wedge at 0x1bd8d480920>,
#   <matplotlib.patches.Wedge at 0x1bd8d480d70>,
#   <matplotlib.patches.Wedge at 0x1bd8d4811f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d481610>,
#   <matplotlib.patches.Wedge at 0x1bd8d481ac0>,
#   <matplotlib.patches.Wedge at 0x1bd8d481f40>,
#   <matplotlib.patches.Wedge at 0x1bd8d4823c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d482810>,
#   <matplotlib.patches.Wedge at 0x1bd8d482c90>,
#   <matplotlib.patches.Wedge at 0x1bd8d4830b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d483500>,
#   <matplotlib.patches.Wedge at 0x1bd8d483980>,
#   <matplotlib.patches.Wedge at 0x1bd8d483dd0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4bc140>,
#   <matplotlib.patches.Wedge at 0x1bd8d4bc6e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4bcb60>,
#   <matplotlib.patches.Wedge at 0x1bd8d4bcfb0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4bd3d0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4bd6a0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4bdc10>,
#   <matplotlib.patches.Wedge at 0x1bd8d4be090>,
#   <matplotlib.patches.Wedge at 0x1bd8d4be4e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4be8d0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4bed50>,
#   <matplotlib.patches.Wedge at 0x1bd8d4bf1a0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4bf5f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4bfa40>,
#   <matplotlib.patches.Wedge at 0x1bd8d4bfec0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f0380>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f0800>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f0c50>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f1070>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f14f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f1970>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f1d90>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f2240>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f26f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f2b40>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f2f90>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f33e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f36e0>,
#   <matplotlib.patches.Wedge at 0x1bd8d4f3cb0>,
#   <matplotlib.patches.Wedge at 0x1bd8d524170>,
#   <matplotlib.patches.Wedge at 0x1bd8d5245f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d524a70>,
#   <matplotlib.patches.Wedge at 0x1bd8d524f20>,
#   <matplotlib.patches.Wedge at 0x1bd8d5253a0>,
#   <matplotlib.patches.Wedge at 0x1bd8d525820>,
#   <matplotlib.patches.Wedge at 0x1bd8d525c70>,
#   <matplotlib.patches.Wedge at 0x1bd8d5260f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d526570>,
#   <matplotlib.patches.Wedge at 0x1bd8d5269c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d526e40>,
#   <matplotlib.patches.Wedge at 0x1bd8d5272c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d5275f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d527bc0>,
#   <matplotlib.patches.Wedge at 0x1bd8d55c050>,
#   <matplotlib.patches.Wedge at 0x1bd8d55c4d0>,
#   <matplotlib.patches.Wedge at 0x1bd8d55c980>,
#   <matplotlib.patches.Wedge at 0x1bd8d55ce00>,
#   <matplotlib.patches.Wedge at 0x1bd8d55d280>,
#   <matplotlib.patches.Wedge at 0x1bd8d55d5b0>,
#   <matplotlib.patches.Wedge at 0x1bd8d55db80>,
#   <matplotlib.patches.Wedge at 0x1bd8d55e000>,
#   <matplotlib.patches.Wedge at 0x1bd8d55e450>,
#   <matplotlib.patches.Wedge at 0x1bd8d55e8a0>,
#   <matplotlib.patches.Wedge at 0x1bd8d55ed20>,
#   <matplotlib.patches.Wedge at 0x1bd8d55f170>,
#   <matplotlib.patches.Wedge at 0x1bd8d55f5c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d55fa10>,
#   <matplotlib.patches.Wedge at 0x1bd8d55fe30>,
#   <matplotlib.patches.Wedge at 0x1bd8d5902c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d590710>,
#   <matplotlib.patches.Wedge at 0x1bd8d590b90>,
#   <matplotlib.patches.Wedge at 0x1bd8d591040>,
#   <matplotlib.patches.Wedge at 0x1bd8d5914c0>,
#   <matplotlib.patches.Wedge at 0x1bd8d591940>,
#   <matplotlib.patches.Wedge at 0x1bd8d591d90>,
#   <matplotlib.patches.Wedge at 0x1bd8d592240>,
#   <matplotlib.patches.Wedge at 0x1bd8d5926f0>,
#   <matplotlib.patches.Wedge at 0x1bd8d592b70>,
#   <matplotlib.patches.Wedge at 0x1bd8d592ff0>,
#   <matplotlib.patches.Wedge at 0x1bd8d593470>,
#   <matplotlib.patches.Wedge at 0x1bde9f24ce0>,
#   <matplotlib.patches.Wedge at 0x1bdf72d4f20>,
#   <matplotlib.patches.Wedge at 0x1bd807d6540>,
#   <matplotlib.patches.Wedge at 0x1bd8277d850>,
#   <matplotlib.patches.Wedge at 0x1bd8095ddf0>,
#   <matplotlib.patches.Wedge at 0x1bd82c08050>,
#   <matplotlib.patches.Wedge at 0x1bd8064aff0>,
#   <matplotlib.patches.Wedge at 0x1bd800607a0>,
#   <matplotlib.patches.Wedge at 0x1bdfd2019a0>,
#   <matplotlib.patches.Wedge at 0x1bdffdd98b0>,
#   <matplotlib.patches.Wedge at 0x1bd825f2090>,
#   <matplotlib.patches.Wedge at 0x1bd82cb3ef0>,
#   <matplotlib.patches.Wedge at 0x1bd81f3c320>,
#   <matplotlib.patches.Wedge at 0x1bd828fcf50>,
#   <matplotlib.patches.Wedge at 0x1bd8209f830>,
#   <matplotlib.patches.Wedge at 0x1bd83146ff0>,
#   <matplotlib.patches.Wedge at 0x1bd80add940>,
#   <matplotlib.patches.Wedge at 0x1bd822e6f60>,
#   <matplotlib.patches.Wedge at 0x1bde98ccd40>,
#   <matplotlib.patches.Wedge at 0x1bd826b5a60>,
#   <matplotlib.patches.Wedge at 0x1bd883bc440>,
#   <matplotlib.patches.Wedge at 0x1bd883bcad0>,
#   <matplotlib.patches.Wedge at 0x1bd883bcf20>,
#   <matplotlib.patches.Wedge at 0x1bd883bd3a0>,
#   <matplotlib.patches.Wedge at 0x1bd883bd9a0>,
#   <matplotlib.patches.Wedge at 0x1bd883bdca0>,
#   <matplotlib.patches.Wedge at 0x1bd883be030>,
#   <matplotlib.patches.Wedge at 0x1bd883be840>,
#   <matplotlib.patches.Wedge at 0x1bd883beb70>,
#   <matplotlib.patches.Wedge at 0x1bd883bf020>,
#   <matplotlib.patches.Wedge at 0x1bd883bf470>,
#   <matplotlib.patches.Wedge at 0x1bd883bf890>,
#   <matplotlib.patches.Wedge at 0x1bd883bff50>,
#   <matplotlib.patches.Wedge at 0x1bd883bdb20>,
#   <matplotlib.patches.Wedge at 0x1bd82f16960>,
#   <matplotlib.patches.Wedge at 0x1bd80ea8710>,
#   <matplotlib.patches.Wedge at 0x1bde9935190>,
#   <matplotlib.patches.Wedge at 0x1bd8328f470>,
#   <matplotlib.patches.Wedge at 0x1bd832af980>,
#   <matplotlib.patches.Wedge at 0x1bd832ac200>,
#   <matplotlib.patches.Wedge at 0x1bd832ad3a0>,
#   <matplotlib.patches.Wedge at 0x1bd832af7a0>,
#   <matplotlib.patches.Wedge at 0x1bd8338d730>,
#   <matplotlib.patches.Wedge at 0x1bd80181970>,
#   <matplotlib.patches.Wedge at 0x1bdf8c10cb0>,
#   <matplotlib.patches.Wedge at 0x1bdefa9a2a0>,
#   <matplotlib.patches.Wedge at 0x1bde98391f0>,
#   <matplotlib.patches.Wedge at 0x1bd832fe900>,
#   <matplotlib.patches.Wedge at 0x1bd8b9dc140>,
#   <matplotlib.patches.Wedge at 0x1bd8b9dc800>,
#   <matplotlib.patches.Wedge at 0x1bd8b9dcc50>,
#   <matplotlib.patches.Wedge at 0x1bd8b9dd040>,
#   <matplotlib.patches.Wedge at 0x1bd8b9dd430>,
#   <matplotlib.patches.Wedge at 0x1bd8b9ddc10>,
#   <matplotlib.patches.Wedge at 0x1bd8b9de240>,
#   <matplotlib.patches.Wedge at 0x1bd8b9de480>,
#   <matplotlib.patches.Wedge at 0x1bd8b9de9f0>,
#   <matplotlib.patches.Wedge at 0x1bd8b9dee70>,
#   <matplotlib.patches.Wedge at 0x1bd8b9df4a0>,
#   <matplotlib.patches.Wedge at 0x1bd8b9df830>,
#   <matplotlib.patches.Wedge at 0x1bd8b9dfce0>,
#   <matplotlib.patches.Wedge at 0x1bd8b9dfe30>,
#   <matplotlib.patches.Wedge at 0x1bd834a1e50>,
#   <matplotlib.patches.Wedge at 0x1bd834a0c50>,
#   <matplotlib.patches.Wedge at 0x1bdfce63350>,
#   <matplotlib.patches.Wedge at 0x1bdfce62270>,
#   <matplotlib.patches.Wedge at 0x1bdfce639b0>,
#   <matplotlib.patches.Wedge at 0x1bdfce61be0>,
#   <matplotlib.patches.Wedge at 0x1bdfcea5e20>,
#   <matplotlib.patches.Wedge at 0x1bdf6fd5880>,
#   <matplotlib.patches.Wedge at 0x1bdeff57170>,
#   <matplotlib.patches.Wedge at 0x1bd801182f0>,
#   <matplotlib.patches.Wedge at 0x1bde9e965d0>,
#   <matplotlib.patches.Wedge at 0x1bd859fd190>,
#   <matplotlib.patches.Wedge at 0x1bde98033e0>,
#   <matplotlib.patches.Wedge at 0x1bd8686ce60>,
#   <matplotlib.patches.Wedge at 0x1bd8686dc10>,
#   <matplotlib.patches.Wedge at 0x1bd8686e510>,
#   <matplotlib.patches.Wedge at 0x1bd8686ee10>,
#   <matplotlib.patches.Wedge at 0x1bd8686d850>,
#   <matplotlib.patches.Wedge at 0x1bd8686f710>,
#   <matplotlib.patches.Wedge at 0x1bd8686cb90>,
#   <matplotlib.patches.Wedge at 0x1bd8a05c9e0>,
#   <matplotlib.patches.Wedge at 0x1bd8a05eae0>,
#   <matplotlib.patches.Wedge at 0x1bd8a05f350>,
#   <matplotlib.patches.Wedge at 0x1bd8a05ec60>,
#   <matplotlib.patches.Wedge at 0x1bd8a05e300>,
#   <matplotlib.patches.Wedge at 0x1bd8a05de50>,
#   <matplotlib.patches.Wedge at 0x1bd8a05f6b0>,
#   <matplotlib.patches.Wedge at 0x1bd831ad610>,
#   <matplotlib.patches.Wedge at 0x1bd831ade50>,
#   <matplotlib.patches.Wedge at 0x1bd831ae0f0>,
#   <matplotlib.patches.Wedge at 0x1bdfcefbef0>,
#   <matplotlib.patches.Wedge at 0x1bd8a185100>,
#   <matplotlib.patches.Wedge at 0x1bd8a184ef0>,
#   <matplotlib.patches.Wedge at 0x1bd8a186c00>,
#   <matplotlib.patches.Wedge at 0x1bd8a186060>,
#   <matplotlib.patches.Wedge at 0x1bd833f85f0>,
#   <matplotlib.patches.Wedge at 0x1bd833f8470>,
#   <matplotlib.patches.Wedge at 0x1bd8344a630>,
#   <matplotlib.patches.Wedge at 0x1bd8344a870>,
#   <matplotlib.patches.Wedge at 0x1bd8a0fcf20>,
#   <matplotlib.patches.Wedge at 0x1bd8a0fd160>,
#   <matplotlib.patches.Wedge at 0x1bd8a0fcfb0>,
#   <matplotlib.patches.Wedge at 0x1bd8a0fd520>,
#   <matplotlib.patches.Wedge at 0x1bd8a0fda00>,
#   <matplotlib.patches.Wedge at 0x1bd8a0fe210>,
#   <matplotlib.patches.Wedge at 0x1bd8a0ff020>,
#   <matplotlib.patches.Wedge at 0x1bd8a0ffc80>,
#   <matplotlib.patches.Wedge at 0x1bd8a0ffe30>,
#   <matplotlib.patches.Wedge at 0x1bd8a0fcd10>,
#   <matplotlib.patches.Wedge at 0x1bd8a0fc200>,
#   <matplotlib.patches.Wedge at 0x1bd8a0fe240>,
#   <matplotlib.patches.Wedge at 0x1bd8a0fef90>,
#   <matplotlib.patches.Wedge at 0x1bd8a0fc7a0>,
#   <matplotlib.patches.Wedge at 0x1bd82f9f710>,
#   <matplotlib.patches.Wedge at 0x1bd82f9f680>,
#   <matplotlib.patches.Wedge at 0x1bd82f9f170>,
#   <matplotlib.patches.Wedge at 0x1bd82f9fb00>,
#   <matplotlib.patches.Wedge at 0x1bdefb77410>,
#   <matplotlib.patches.Wedge at 0x1bdefb75790>,
#   <matplotlib.patches.Wedge at 0x1bdefb74d70>,
#   <matplotlib.patches.Wedge at 0x1bdefb76d80>,
#   <matplotlib.patches.Wedge at 0x1bdefb761e0>,
#   <matplotlib.patches.Wedge at 0x1bdefb77740>,
#   <matplotlib.patches.Wedge at 0x1bdefb771d0>,
#   <matplotlib.patches.Wedge at 0x1bdefb74380>,
#   <matplotlib.patches.Wedge at 0x1bdefb76ae0>,
#   <matplotlib.patches.Wedge at 0x1bdfd0ea4e0>,
#   <matplotlib.patches.Wedge at 0x1bd87a24650>,
#   <matplotlib.patches.Wedge at 0x1bd87a25250>,
#   <matplotlib.patches.Wedge at 0x1bd87a24260>,
#   <matplotlib.patches.Wedge at 0x1bd87a25ee0>,
#   <matplotlib.patches.Wedge at 0x1bd87a26a80>,
#   <matplotlib.patches.Wedge at 0x1bd87a277d0>,
#   <matplotlib.patches.Wedge at 0x1bd87a26600>,
#   <matplotlib.patches.Wedge at 0x1bd87a279b0>,
#   <matplotlib.patches.Wedge at 0x1bd87a26cf0>,
#   <matplotlib.patches.Wedge at 0x1bd87a26c90>,
#   <matplotlib.patches.Wedge at 0x1bd87a27020>,
#   <matplotlib.patches.Wedge at 0x1bd87a24b90>,
#   <matplotlib.patches.Wedge at 0x1bd87a26450>,
#   <matplotlib.patches.Wedge at 0x1bd87a25850>,
#   <matplotlib.patches.Wedge at 0x1bd801e3b30>,
#   <matplotlib.patches.Wedge at 0x1bd88b14770>,
#   <matplotlib.patches.Wedge at 0x1bd88b14410>,
#   <matplotlib.patches.Wedge at 0x1bd88b153d0>,
#   <matplotlib.patches.Wedge at 0x1bd88b16120>,
#   <matplotlib.patches.Wedge at 0x1bd88b17410>,
#   <matplotlib.patches.Wedge at 0x1bd88b15d90>,
#   <matplotlib.patches.Wedge at 0x1bd88b152b0>,
#   <matplotlib.patches.Wedge at 0x1bd88b157c0>,
#   <matplotlib.patches.Wedge at 0x1bd88b15430>,
#   <matplotlib.patches.Wedge at 0x1bd88b143e0>,
#   <matplotlib.patches.Wedge at 0x1bd88b14c20>,
#   <matplotlib.patches.Wedge at 0x1bd88b16090>,
#   <matplotlib.patches.Wedge at 0x1bd88b174d0>,
#   <matplotlib.patches.Wedge at 0x1bd88b141d0>,
#   <matplotlib.patches.Wedge at 0x1bd8a9501d0>,
#   <matplotlib.patches.Wedge at 0x1bd8a9506b0>,
#   <matplotlib.patches.Wedge at 0x1bd8a950920>,
#   <matplotlib.patches.Wedge at 0x1bd8a951010>,
#   <matplotlib.patches.Wedge at 0x1bd8a951a30>,
#   <matplotlib.patches.Wedge at 0x1bd8a9519a0>,
#   <matplotlib.patches.Wedge at 0x1bd8a9521b0>,
#   <matplotlib.patches.Wedge at 0x1bd8a952660>,
#   <matplotlib.patches.Wedge at 0x1bd8a952f60>,
#   <matplotlib.patches.Wedge at 0x1bd8a952ea0>,
#   <matplotlib.patches.Wedge at 0x1bd8a9537a0>,
#   <matplotlib.patches.Wedge at 0x1bd8a953bf0>,
#   <matplotlib.patches.Wedge at 0x1bd8a9503e0>,
#   <matplotlib.patches.Wedge at 0x1bd8a9522a0>,
#   <matplotlib.patches.Wedge at 0x1bd82f349e0>,
#   <matplotlib.patches.Wedge at 0x1bd82f347a0>,
#   <matplotlib.patches.Wedge at 0x1bd85a46030>,
#   <matplotlib.patches.Wedge at 0x1bd85a44710>,
#   <matplotlib.patches.Wedge at 0x1bd85c6e420>,
#   <matplotlib.patches.Wedge at 0x1bd83095df0>,
#   <matplotlib.patches.Wedge at 0x1bd83094350>,
#   <matplotlib.patches.Wedge at 0x1bd83096660>,
#   <matplotlib.patches.Wedge at 0x1bd830976b0>,
#   <matplotlib.patches.Wedge at 0x1bd830959a0>,
#   <matplotlib.patches.Wedge at 0x1bd83096c90>,
#   <matplotlib.patches.Wedge at 0x1bd83097fe0>,
#   <matplotlib.patches.Wedge at 0x1bd83095c70>,
#   <matplotlib.patches.Wedge at 0x1bd83096630>,
#   <matplotlib.patches.Wedge at 0x1bd830978f0>,
#   <matplotlib.patches.Wedge at 0x1bd83094b90>,
#   <matplotlib.patches.Wedge at 0x1bd83095010>,
#   <matplotlib.patches.Wedge at 0x1bd89ec4590>,
#   <matplotlib.patches.Wedge at 0x1bd89ec60f0>,
#   <matplotlib.patches.Wedge at 0x1bd89ec5280>,
#   <matplotlib.patches.Wedge at 0x1bd89ec6810>,
#   <matplotlib.patches.Wedge at 0x1bd89ec58b0>,
#   <matplotlib.patches.Wedge at 0x1bd89ec6ae0>,
#   <matplotlib.patches.Wedge at 0x1bd89ec6e40>,
#   <matplotlib.patches.Wedge at 0x1bd89ec7e60>,
#   <matplotlib.patches.Wedge at 0x1bd89ec5d30>,
#   <matplotlib.patches.Wedge at 0x1bd89ec5460>,
#   <matplotlib.patches.Wedge at 0x1bd89ec7c20>,
#   <matplotlib.patches.Wedge at 0x1bd89ec7f20>,
#   <matplotlib.patches.Wedge at 0x1bd89ec62a0>,
#   <matplotlib.patches.Wedge at 0x1bd89ec7dd0>,
#   <matplotlib.patches.Wedge at 0x1bd8a1bd6a0>,
#   <matplotlib.patches.Wedge at 0x1bd8a1bf980>,
#   <matplotlib.patches.Wedge at 0x1bd8a1bddf0>,
#   <matplotlib.patches.Wedge at 0x1bd8a1bc350>,
#   <matplotlib.patches.Wedge at 0x1bd83024050>,
#   <matplotlib.patches.Wedge at 0x1bd83024fb0>,
#   <matplotlib.patches.Wedge at 0x1bd83025250>,
#   <matplotlib.patches.Wedge at 0x1bd83026150>,
#   <matplotlib.patches.Wedge at 0x1bd83026990>,
#   <matplotlib.patches.Wedge at 0x1bd83027950>,
#   <matplotlib.patches.Wedge at 0x1bd83024b00>,
#   <matplotlib.patches.Wedge at 0x1bd83026ea0>,
#   <matplotlib.patches.Wedge at 0x1bd83027740>,
#   <matplotlib.patches.Wedge at 0x1bd830245c0>,
#   <matplotlib.patches.Wedge at 0x1bd83024410>,
#   <matplotlib.patches.Wedge at 0x1bd83024cb0>,
#   <matplotlib.patches.Wedge at 0x1bd830274a0>,
#   <matplotlib.patches.Wedge at 0x1bd83026ae0>,
#   <matplotlib.patches.Wedge at 0x1bd83026a80>,
#   <matplotlib.patches.Wedge at 0x1bdefb903b0>,
#   <matplotlib.patches.Wedge at 0x1bd831cac00>,
#   <matplotlib.patches.Wedge at 0x1bd831c9460>,
#   <matplotlib.patches.Wedge at 0x1bd86778740>,
#   <matplotlib.patches.Wedge at 0x1bd86779250>,
#   <matplotlib.patches.Wedge at 0x1bd867787d0>,
#   <matplotlib.patches.Wedge at 0x1bd86778620>,
#   <matplotlib.patches.Wedge at 0x1bd8677aa20>,
#   <matplotlib.patches.Wedge at 0x1bd8677af00>,
#   <matplotlib.patches.Wedge at 0x1bd8677ac30>,
#   <matplotlib.patches.Wedge at 0x1bd8677acc0>,
#   <matplotlib.patches.Wedge at 0x1bd8677a720>,
#   <matplotlib.patches.Wedge at 0x1bd867799a0>,
#   <matplotlib.patches.Wedge at 0x1bd8677bcb0>,
#   <matplotlib.patches.Wedge at 0x1bd86779d90>,
#   <matplotlib.patches.Wedge at 0x1bd8677a510>,
#   <matplotlib.patches.Wedge at 0x1bdfceba060>,
#   <matplotlib.patches.Wedge at 0x1bdfcebb110>,
#   <matplotlib.patches.Wedge at 0x1bd881febd0>,
#   <matplotlib.patches.Wedge at 0x1bd881ff620>,
#   <matplotlib.patches.Wedge at 0x1bd881fdaf0>,
#   <matplotlib.patches.Wedge at 0x1bd881fe690>,
#   <matplotlib.patches.Wedge at 0x1bd881fc800>,
#   <matplotlib.patches.Wedge at 0x1bd881feab0>,
#   <matplotlib.patches.Wedge at 0x1bd881fe120>,
#   <matplotlib.patches.Wedge at 0x1bd881fe360>,
#   <matplotlib.patches.Wedge at 0x1bd881fcb00>,
#   <matplotlib.patches.Wedge at 0x1bd881ff740>,
#   <matplotlib.patches.Wedge at 0x1bd881fca10>,
#   <matplotlib.patches.Wedge at 0x1bd881fcf50>,
#   <matplotlib.patches.Wedge at 0x1bd881ff2f0>,
#   <matplotlib.patches.Wedge at 0x1bd881ff9e0>,
#   <matplotlib.patches.Wedge at 0x1bd8abbc320>,
#   <matplotlib.patches.Wedge at 0x1bd8abbc680>,
#   <matplotlib.patches.Wedge at 0x1bd8abbccb0>,
#   <matplotlib.patches.Wedge at 0x1bd8abbd670>,
#   <matplotlib.patches.Wedge at 0x1bd8abbd5b0>,
#   <matplotlib.patches.Wedge at 0x1bd8abbdee0>,
#   <matplotlib.patches.Wedge at 0x1bd8abbe570>,
#   <matplotlib.patches.Wedge at 0x1bd8abbe690>,
#   <matplotlib.patches.Wedge at 0x1bd8abbee40>,
#   <matplotlib.patches.Wedge at 0x1bd8abbf440>,
#   <matplotlib.patches.Wedge at 0x1bd8abbfb60>,
#   <matplotlib.patches.Wedge at 0x1bd8abbfec0>,
#   <matplotlib.patches.Wedge at 0x1bd8abbf800>,
#   <matplotlib.patches.Wedge at 0x1bd8abbfd70>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9c380>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9c5c0>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9ce60>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9d0d0>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9d9a0>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9da90>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9e360>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9e6c0>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9eb40>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9f410>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9f500>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9fc20>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9c170>,
#   <matplotlib.patches.Wedge at 0x1bd8ac9e9c0>,
#   <matplotlib.patches.Wedge at 0x1bdf703ff50>,
#   <matplotlib.patches.Wedge at 0x1bdf703c470>,
#   <matplotlib.patches.Wedge at 0x1bdf703d100>,
#   <matplotlib.patches.Wedge at 0x1bdf703f710>,
#   <matplotlib.patches.Wedge at 0x1bd82fc60c0>,
#   <matplotlib.patches.Wedge at 0x1bd82fc66f0>,
#   <matplotlib.patches.Wedge at 0x1bd82fc6f30>,
#   <matplotlib.patches.Wedge at 0x1bd82fc7b30>,
#   <matplotlib.patches.Wedge at 0x1bd82fc4c20>,
#   <matplotlib.patches.Wedge at 0x1bd82fc52e0>,
#   <matplotlib.patches.Wedge at 0x1bd82fc5940>,
#   <matplotlib.patches.Wedge at 0x1bd82fc7710>,
#   <matplotlib.patches.Wedge at 0x1bd82fc6960>,
#   <matplotlib.patches.Wedge at 0x1bd82fc4a40>,
#   <matplotlib.patches.Wedge at 0x1bd85e22120>,
#   <matplotlib.patches.Wedge at 0x1bd85e20440>,
#   <matplotlib.patches.Wedge at 0x1bd85e20950>,
#   <matplotlib.patches.Wedge at 0x1bd85e21970>,
#   <matplotlib.patches.Wedge at 0x1bd85e21e50>,
#   <matplotlib.patches.Wedge at 0x1bd85e22750>,
#   <matplotlib.patches.Wedge at 0x1bd85e21b50>,
#   <matplotlib.patches.Wedge at 0x1bd85e20620>,
#   <matplotlib.patches.Wedge at 0x1bd85e23c80>,
#   <matplotlib.patches.Wedge at 0x1bd82fc6fc0>,
#   <matplotlib.patches.Wedge at 0x1bd85e214c0>,
#   <matplotlib.patches.Wedge at 0x1bd85e23080>,
#   <matplotlib.patches.Wedge at 0x1bd85e22ea0>,
#   <matplotlib.patches.Wedge at 0x1bd85e233b0>,
#   <matplotlib.patches.Wedge at 0x1bdfce774d0>,
#   <matplotlib.patches.Wedge at 0x1bdfce752b0>,
#   <matplotlib.patches.Wedge at 0x1bdfce74a70>,
#   <matplotlib.patches.Wedge at 0x1bdfce76000>,
#   <matplotlib.patches.Wedge at 0x1bdfce74dd0>,
#   <matplotlib.patches.Wedge at 0x1bdfce74680>,
#   <matplotlib.patches.Wedge at 0x1bd84b15880>,
#   <matplotlib.patches.Wedge at 0x1bd84b16cf0>,
#   <matplotlib.patches.Wedge at 0x1bd84b17650>,
#   <matplotlib.patches.Wedge at 0x1bd84b14bf0>,
#   <matplotlib.patches.Wedge at 0x1bd84b17740>,
#   <matplotlib.patches.Wedge at 0x1bd84b15790>,
#   <matplotlib.patches.Wedge at 0x1bd84b15dc0>,
#   <matplotlib.patches.Wedge at 0x1bd87d103e0>,
#   <matplotlib.patches.Wedge at 0x1bd87d10290>,
#   <matplotlib.patches.Wedge at 0x1bd87d11550>,
#   <matplotlib.patches.Wedge at 0x1bd87d101d0>,
#   <matplotlib.patches.Wedge at 0x1bd87d12330>,
#   <matplotlib.patches.Wedge at 0x1bd87d10170>,
#   <matplotlib.patches.Wedge at 0x1bd87d13fe0>,
#   <matplotlib.patches.Wedge at 0x1bd87d13350>,
#   <matplotlib.patches.Wedge at 0x1bd87d13cb0>,
#   <matplotlib.patches.Wedge at 0x1bd87d11e20>,
#   <matplotlib.patches.Wedge at 0x1bd87d10c50>,
#   <matplotlib.patches.Wedge at 0x1bd87d11070>,
#   <matplotlib.patches.Wedge at 0x1bd87d13e90>,
#   <matplotlib.patches.Wedge at 0x1bd87d12780>,
#   <matplotlib.patches.Wedge at 0x1bd830ef4a0>,
#   <matplotlib.patches.Wedge at 0x1bd830ec170>,
#   <matplotlib.patches.Wedge at 0x1bd830ef320>,
#   <matplotlib.patches.Wedge at 0x1bd830eea20>,
#   <matplotlib.patches.Wedge at 0x1bd830eddf0>,
#   <matplotlib.patches.Wedge at 0x1bd830ecbc0>,
#   <matplotlib.patches.Wedge at 0x1bd85808c20>,
#   <matplotlib.patches.Wedge at 0x1bd85808f50>,
#   <matplotlib.patches.Wedge at 0x1bd85808ad0>,
#   <matplotlib.patches.Wedge at 0x1bd8580a210>,
#   <matplotlib.patches.Wedge at 0x1bd830ed1c0>,
#   <matplotlib.patches.Wedge at 0x1bd8580b4d0>,
#   <matplotlib.patches.Wedge at 0x1bd8580a390>,
#   <matplotlib.patches.Wedge at 0x1bd8580bbc0>,
#   <matplotlib.patches.Wedge at 0x1bd8580b230>,
#   <matplotlib.patches.Wedge at 0x1bd8580a780>,
#   <matplotlib.patches.Wedge at 0x1bd85809730>,
#   <matplotlib.patches.Wedge at 0x1bd8580acc0>,
#   <matplotlib.patches.Wedge at 0x1bd85809250>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f4c80>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f5e50>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f42c0>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f48c0>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f4b90>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f45f0>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f6510>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f58b0>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f79e0>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f6ea0>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f7da0>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f5cd0>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f6690>,
#   <matplotlib.patches.Wedge at 0x1bd8a1f75c0>,
#   <matplotlib.patches.Wedge at 0x1bd84888ec0>,
#   <matplotlib.patches.Wedge at 0x1bd848894f0>,
#   <matplotlib.patches.Wedge at 0x1bd84889c40>,
#   <matplotlib.patches.Wedge at 0x1bd84889610>,
#   <matplotlib.patches.Wedge at 0x1bd8488a990>,
#   <matplotlib.patches.Wedge at 0x1bd8488b4d0>,
#   <matplotlib.patches.Wedge at 0x1bd8488a0f0>,
#   <matplotlib.patches.Wedge at 0x1bd84889130>,
#   <matplotlib.patches.Wedge at 0x1bd84889220>,
#   <matplotlib.patches.Wedge at 0x1bd8488a810>,
#   <matplotlib.patches.Wedge at 0x1bd8488bf80>,
#   <matplotlib.patches.Wedge at 0x1bd84888f20>,
#   <matplotlib.patches.Wedge at 0x1bd8a470740>,
#   <matplotlib.patches.Wedge at 0x1bd8a470620>,
#   <matplotlib.patches.Wedge at 0x1bd8a471100>,
#   <matplotlib.patches.Wedge at 0x1bd8a471610>,
#   <matplotlib.patches.Wedge at 0x1bd8a472810>,
#   <matplotlib.patches.Wedge at 0x1bd8a472270>,
#   <matplotlib.patches.Wedge at 0x1bd8a470680>,
#   <matplotlib.patches.Wedge at 0x1bd8a4731a0>,
#   <matplotlib.patches.Wedge at 0x1bd8a473dd0>,
#   <matplotlib.patches.Wedge at 0x1bd8a4735c0>,
#   <matplotlib.patches.Wedge at 0x1bd8a473950>,
#   <matplotlib.patches.Wedge at 0x1bd8a473e90>,
#   <matplotlib.patches.Wedge at 0x1bd8a472420>,
#   <matplotlib.patches.Wedge at 0x1bd8a4739e0>,
#   <matplotlib.patches.Wedge at 0x1bd8a472780>,
#   <matplotlib.patches.Wedge at 0x1bd84a3c7d0>,
#   <matplotlib.patches.Wedge at 0x1bd84a3ce60>,
#   <matplotlib.patches.Wedge at 0x1bd84a3ca40>,
#   <matplotlib.patches.Wedge at 0x1bd84a3e2d0>,
#   <matplotlib.patches.Wedge at 0x1bd84a3dfd0>,
#   <matplotlib.patches.Wedge at 0x1bd84a3e480>,
#   <matplotlib.patches.Wedge at 0x1bd84a3ea20>,
#   <matplotlib.patches.Wedge at 0x1bd84a3e3c0>,
#   <matplotlib.patches.Wedge at 0x1bd84a3e570>,
#   <matplotlib.patches.Wedge at 0x1bd84a3fb00>,
#   <matplotlib.patches.Wedge at 0x1bd84a3f890>,
#   <matplotlib.patches.Wedge at 0x1bd84a3e780>,
#   <matplotlib.patches.Wedge at 0x1bd84a3d6a0>,
#   <matplotlib.patches.Wedge at 0x1bd84a3dc70>,
#   <matplotlib.patches.Wedge at 0x1bd83487650>,
#   <matplotlib.patches.Wedge at 0x1bd853a4440>,
#   <matplotlib.patches.Wedge at 0x1bd853a4b30>,
#   <matplotlib.patches.Wedge at 0x1bd853a4e90>,
#   <matplotlib.patches.Wedge at 0x1bd853a5190>,
#   <matplotlib.patches.Wedge at 0x1bd853a59d0>,
#   <matplotlib.patches.Wedge at 0x1bd853a5f40>,
#   <matplotlib.patches.Wedge at 0x1bd853a6240>,
#   <matplotlib.patches.Wedge at 0x1bd853a6090>,
#   <matplotlib.patches.Wedge at 0x1bd853a6ed0>,
#   <matplotlib.patches.Wedge at 0x1bd853a7110>,
#   <matplotlib.patches.Wedge at 0x1bd853a79e0>,
#   <matplotlib.patches.Wedge at 0x1bd853a7da0>,
#   <matplotlib.patches.Wedge at 0x1bd853a7530>,
#   <matplotlib.patches.Wedge at 0x1bd853a5b80>,
#   <matplotlib.patches.Wedge at 0x1bd8689c9b0>,
#   <matplotlib.patches.Wedge at 0x1bd8689d700>,
#   <matplotlib.patches.Wedge at 0x1bd8689cd40>,
#   <matplotlib.patches.Wedge at 0x1bd8689e240>,
#   <matplotlib.patches.Wedge at 0x1bd8689e720>,
#   <matplotlib.patches.Wedge at 0x1bd8689ecf0>,
#   <matplotlib.patches.Wedge at 0x1bd8689f770>,
#   <matplotlib.patches.Wedge at 0x1bd8689eb70>,
#   <matplotlib.patches.Wedge at 0x1bd8689fd10>,
#   <matplotlib.patches.Wedge at 0x1bd8689d9d0>,
#   <matplotlib.patches.Wedge at 0x1bd8689d7f0>,
#   <matplotlib.patches.Wedge at 0x1bd8689f740>,
#   <matplotlib.patches.Wedge at 0x1bd8689ca70>,
#   <matplotlib.patches.Wedge at 0x1bd8689fbf0>,
#   <matplotlib.patches.Wedge at 0x1bd84934260>,
#   <matplotlib.patches.Wedge at 0x1bd84934530>,
#   <matplotlib.patches.Wedge at 0x1bd84934e30>,
#   <matplotlib.patches.Wedge at 0x1bd849351c0>,
#   <matplotlib.patches.Wedge at 0x1bd849358e0>,
#   <matplotlib.patches.Wedge at 0x1bd84935e50>,
#   <matplotlib.patches.Wedge at 0x1bd849368d0>,
#   <matplotlib.patches.Wedge at 0x1bd849368a0>,
#   <matplotlib.patches.Wedge at 0x1bd84937470>,
#   <matplotlib.patches.Wedge at 0x1bd849376e0>,
#   <matplotlib.patches.Wedge at 0x1bd84937710>,
#   <matplotlib.patches.Wedge at 0x1bd84935fa0>,
#   <matplotlib.patches.Wedge at 0x1bd84936300>,
#   <matplotlib.patches.Wedge at 0x1bd84935100>,
#   <matplotlib.patches.Wedge at 0x1bd8a9f8080>,
#   <matplotlib.patches.Wedge at 0x1bd8a9f85c0>,
#   <matplotlib.patches.Wedge at 0x1bd8a9f8800>,
#   <matplotlib.patches.Wedge at 0x1bd8a9f91f0>,
#   <matplotlib.patches.Wedge at 0x1bd8a9f9760>,
#   <matplotlib.patches.Wedge at 0x1bd8a9f9b50>,
#   <matplotlib.patches.Wedge at 0x1bd8a9f9e50>,
#   <matplotlib.patches.Wedge at 0x1bd8a9fa870>,
#   <matplotlib.patches.Wedge at 0x1bd8a9fac30>,
#   <matplotlib.patches.Wedge at 0x1bd8a9faf30>,
#   <matplotlib.patches.Wedge at 0x1bd8a9fb860>,
#   <matplotlib.patches.Wedge at 0x1bd8a9fbbf0>,
#   <matplotlib.patches.Wedge at 0x1bd8a9f8e30>,
#   <matplotlib.patches.Wedge at 0x1bd8a9fbc80>,
#   <matplotlib.patches.Wedge at 0x1bd879e6720>,
#   <matplotlib.patches.Wedge at 0x1bd84bc0590>,
#   <matplotlib.patches.Wedge at 0x1bd84bc1610>,
#   <matplotlib.patches.Wedge at 0x1bd84bc2390>,
#   <matplotlib.patches.Wedge at 0x1bd84bc00b0>,
#   <matplotlib.patches.Wedge at 0x1bd84bc24e0>,
#   <matplotlib.patches.Wedge at 0x1bd84bc0140>,
#   <matplotlib.patches.Wedge at 0x1bd84bc3b60>,
#   <matplotlib.patches.Wedge at 0x1bd84bc0800>,
#   <matplotlib.patches.Wedge at 0x1bd84bc0320>,
#   <matplotlib.patches.Wedge at 0x1bd84bc2a80>,
#   <matplotlib.patches.Wedge at 0x1bd84bc2b10>,
#   <matplotlib.patches.Wedge at 0x1bd84bc39e0>,
#   <matplotlib.patches.Wedge at 0x1bd84bc38c0>,
#   <matplotlib.patches.Wedge at 0x1bd84bc3aa0>,
#   <matplotlib.patches.Wedge at 0x1bd8541ce60>,
#   <matplotlib.patches.Wedge at 0x1bd8541cbc0>,
#   <matplotlib.patches.Wedge at 0x1bd8541d4c0>,
#   <matplotlib.patches.Wedge at 0x1bd8541d910>,
#   <matplotlib.patches.Wedge at 0x1bd8541e3f0>,
#   <matplotlib.patches.Wedge at 0x1bd8541e150>,
#   <matplotlib.patches.Wedge at 0x1bd8541d460>,
#   <matplotlib.patches.Wedge at 0x1bd8541e090>,
#   <matplotlib.patches.Wedge at 0x1bd8541ffe0>,
#   <matplotlib.patches.Wedge at 0x1bd8541f410>,
#   <matplotlib.patches.Wedge at 0x1bd8541c5f0>,
#   <matplotlib.patches.Wedge at 0x1bd8541ff50>,
#   <matplotlib.patches.Wedge at 0x1bd8541c4d0>,
#   <matplotlib.patches.Wedge at 0x1bd8541e540>,
#   <matplotlib.patches.Wedge at 0x1bd84886cc0>,
#   <matplotlib.patches.Wedge at 0x1bd84887e60>,
#   <matplotlib.patches.Wedge at 0x1bd848877d0>,
#   <matplotlib.patches.Wedge at 0x1bd84884a10>,
#   <matplotlib.patches.Wedge at 0x1bd848853d0>,
#   <matplotlib.patches.Wedge at 0x1bd84885010>,
#   <matplotlib.patches.Wedge at 0x1bd84886b10>,
#   <matplotlib.patches.Wedge at 0x1bd848859a0>,
#   <matplotlib.patches.Wedge at 0x1bd84884c80>,
#   <matplotlib.patches.Wedge at 0x1bd84887ad0>,
#   <matplotlib.patches.Wedge at 0x1bd848861e0>,
#   <matplotlib.patches.Wedge at 0x1bd84886420>,
#   <matplotlib.patches.Wedge at 0x1bd84887da0>,
#   <matplotlib.patches.Wedge at 0x1bd89c10620>,
#   <matplotlib.patches.Wedge at 0x1bd89c11220>,
#   <matplotlib.patches.Wedge at 0x1bd89c12000>,
#   <matplotlib.patches.Wedge at 0x1bd89c12450>,
#   <matplotlib.patches.Wedge at 0x1bd89c12d20>,
#   <matplotlib.patches.Wedge at 0x1bd89c13920>,
#   <matplotlib.patches.Wedge at 0x1bd89c125d0>,
#   <matplotlib.patches.Wedge at 0x1bd89c10e00>,
#   <matplotlib.patches.Wedge at 0x1bd89c13c80>,
#   <matplotlib.patches.Wedge at 0x1bd89c12510>,
#   <matplotlib.patches.Wedge at 0x1bd89c13dd0>,
#   <matplotlib.patches.Wedge at 0x1bd89c13650>,
#   <matplotlib.patches.Wedge at 0x1bd89c12120>,
#   <matplotlib.patches.Wedge at 0x1bd89c12810>,
#   <matplotlib.patches.Wedge at 0x1bd89c12630>,
#   <matplotlib.patches.Wedge at 0x1bd85b4c3e0>,
#   <matplotlib.patches.Wedge at 0x1bd85b4ce60>,
#   <matplotlib.patches.Wedge at 0x1bd85b4cef0>,
#   <matplotlib.patches.Wedge at 0x1bd85b4d670>,
#   <matplotlib.patches.Wedge at 0x1bd85b4db50>,
#   <matplotlib.patches.Wedge at 0x1bd85b4dfd0>,
#   <matplotlib.patches.Wedge at 0x1bd85b4e660>,
#   <matplotlib.patches.Wedge at 0x1bd85b4e750>,
#   <matplotlib.patches.Wedge at 0x1bd85b4f0e0>,
#   <matplotlib.patches.Wedge at 0x1bd85b4f620>,
#   <matplotlib.patches.Wedge at 0x1bd85b4f9b0>,
#   <matplotlib.patches.Wedge at 0x1bd85b4fd40>,
#   <matplotlib.patches.Wedge at 0x1bd85b4cbc0>,
#   <matplotlib.patches.Wedge at 0x1bd85b4cb60>,
#   <matplotlib.patches.Wedge at 0x1bd832c8fb0>,
#   <matplotlib.patches.Wedge at 0x1bdfcec9880>,
#   <matplotlib.patches.Wedge at 0x1bd89f3c680>,
#   <matplotlib.patches.Wedge at 0x1bd89f3dac0>,
#   <matplotlib.patches.Wedge at 0x1bd89f3e2a0>,
#   <matplotlib.patches.Wedge at 0x1bd89f3e6f0>,
#   <matplotlib.patches.Wedge at 0x1bd89f3e180>,
#   <matplotlib.patches.Wedge at 0x1bd89f3eba0>,
#   <matplotlib.patches.Wedge at 0x1bd89f3ec60>,
#   <matplotlib.patches.Wedge at 0x1bd89f3cc20>,
#   <matplotlib.patches.Wedge at 0x1bd89f3e030>,
#   <matplotlib.patches.Wedge at 0x1bd89f3f710>,
#   <matplotlib.patches.Wedge at 0x1bd89f3ed80>,
#   <matplotlib.patches.Wedge at 0x1bd89f3da00>,
#   <matplotlib.patches.Wedge at 0x1bd89f3dca0>,
#   <matplotlib.patches.Wedge at 0x1bd89f3f380>,
#   <matplotlib.patches.Wedge at 0x1bd8a00b8f0>,
#   <matplotlib.patches.Wedge at 0x1bd8a00a480>,
#   <matplotlib.patches.Wedge at 0x1bd8a009d60>,
#   <matplotlib.patches.Wedge at 0x1bd8a00b6e0>,
#   <matplotlib.patches.Wedge at 0x1bd8a008230>,
#   <matplotlib.patches.Wedge at 0x1bd8a008bf0>,
#   <matplotlib.patches.Wedge at 0x1bd8a009340>,
#   <matplotlib.patches.Wedge at 0x1bd8a008ce0>,
#   <matplotlib.patches.Wedge at 0x1bd8a009d30>,
#   <matplotlib.patches.Wedge at 0x1bd8a00abd0>,
#   <matplotlib.patches.Wedge at 0x1bd8a00b290>,
#   <matplotlib.patches.Wedge at 0x1bd8a00b320>,
#   <matplotlib.patches.Wedge at 0x1bd8a008d40>,
#   <matplotlib.patches.Wedge at 0x1bd8a00ade0>,
#   <matplotlib.patches.Wedge at 0x1bd8325b800>,
#   <matplotlib.patches.Wedge at 0x1bdf6f28f20>,
#   <matplotlib.patches.Wedge at 0x1bdf6f29220>,
#   <matplotlib.patches.Wedge at 0x1bd88241b80>,
#   <matplotlib.patches.Wedge at 0x1bd88242cf0>,
#   <matplotlib.patches.Wedge at 0x1bd88241e50>,
#   <matplotlib.patches.Wedge at 0x1bd88240740>,
#   <matplotlib.patches.Wedge at 0x1bd882406b0>,
#   <matplotlib.patches.Wedge at 0x1bd88240c80>,
#   <matplotlib.patches.Wedge at 0x1bd88241fa0>,
#   <matplotlib.patches.Wedge at 0x1bd882403e0>,
#   <matplotlib.patches.Wedge at 0x1bd88242720>,
#   <matplotlib.patches.Wedge at 0x1bd882423f0>,
#   <matplotlib.patches.Wedge at 0x1bd882400e0>,
#   <matplotlib.patches.Wedge at 0x1bd882422a0>,
#   <matplotlib.patches.Wedge at 0x1bd88243860>,
#   <matplotlib.patches.Wedge at 0x1bd8a0301d0>,
#   <matplotlib.patches.Wedge at 0x1bd8a0320f0>,
#   <matplotlib.patches.Wedge at 0x1bd8a031d90>,
#   <matplotlib.patches.Wedge at 0x1bd8a032a50>,
#   <matplotlib.patches.Wedge at 0x1bd8a033590>,
#   <matplotlib.patches.Wedge at 0x1bd8a032870>,
#   <matplotlib.patches.Wedge at 0x1bd8a032e40>,
#   <matplotlib.patches.Wedge at 0x1bd8a033920>,
#   <matplotlib.patches.Wedge at 0x1bd8a030860>,
#   <matplotlib.patches.Wedge at 0x1bd8a0325d0>,
#   <matplotlib.patches.Wedge at 0x1bd8a031b50>,
#   <matplotlib.patches.Wedge at 0x1bd8a033830>,
#   <matplotlib.patches.Wedge at 0x1bd8a032d20>,
#   <matplotlib.patches.Wedge at 0x1bd8a0335f0>,
#   <matplotlib.patches.Wedge at 0x1bde9868c50>,
#   <matplotlib.patches.Wedge at 0x1bd87ed8320>,
#   <matplotlib.patches.Wedge at 0x1bd87eda510>,
#   <matplotlib.patches.Wedge at 0x1bd87ed9f70>,
#   <matplotlib.patches.Wedge at 0x1bd87edad80>,
#   <matplotlib.patches.Wedge at 0x1bd87edbad0>,
#   <matplotlib.patches.Wedge at 0x1bd87edba40>,
#   <matplotlib.patches.Wedge at 0x1bd87ed8bc0>,
#   <matplotlib.patches.Wedge at 0x1bd87eda600>,
#   <matplotlib.patches.Wedge at 0x1bd87ed8d10>,
#   <matplotlib.patches.Wedge at 0x1bd87edbfe0>,
#   <matplotlib.patches.Wedge at 0x1bd87ed8b00>,
#   <matplotlib.patches.Wedge at 0x1bd87ed9fa0>,
#   <matplotlib.patches.Wedge at 0x1bd87edaf00>,
#   <matplotlib.patches.Wedge at 0x1bd87ed8620>,
#   <matplotlib.patches.Wedge at 0x1bd833555e0>,
#   <matplotlib.patches.Wedge at 0x1bd8a0a1160>,
#   <matplotlib.patches.Wedge at 0x1bd8a0a3110>,
#   <matplotlib.patches.Wedge at 0x1bd8a0a1fd0>,
#   <matplotlib.patches.Wedge at 0x1bd8a0a0dd0>,
#   <matplotlib.patches.Wedge at 0x1bd8a0a3a40>,
#   <matplotlib.patches.Wedge at 0x1bd8a0a01a0>,
#   <matplotlib.patches.Wedge at 0x1bd8a0a1e80>,
#   <matplotlib.patches.Wedge at 0x1bd8a0a1130>,
#   <matplotlib.patches.Wedge at 0x1bd8a0a3d10>,
#   <matplotlib.patches.Wedge at 0x1bd8a0a18e0>,
#   <matplotlib.patches.Wedge at 0x1bd8a0a2c30>,
#   <matplotlib.patches.Wedge at 0x1bd8a0a2ae0>,
#   <matplotlib.patches.Wedge at 0x1bd89feb4a0>,
#   <matplotlib.patches.Wedge at 0x1bd89feac90>,
#   <matplotlib.patches.Wedge at 0x1bd89febf50>,
#   <matplotlib.patches.Wedge at 0x1bd89feb260>,
#   <matplotlib.patches.Wedge at 0x1bd89feb7a0>,
#   <matplotlib.patches.Wedge at 0x1bd89fea930>,
#   <matplotlib.patches.Wedge at 0x1bd89fe9580>,
#   <matplotlib.patches.Wedge at 0x1bd89fe9310>,
#   <matplotlib.patches.Wedge at 0x1bd89fe90d0>,
#   <matplotlib.patches.Wedge at 0x1bd89fe8740>,
#   <matplotlib.patches.Wedge at 0x1bd89fea180>,
#   <matplotlib.patches.Wedge at 0x1bd89feb4d0>,
#   <matplotlib.patches.Wedge at 0x1bd89fea5d0>,
#   <matplotlib.patches.Wedge at 0x1bd89fe8b60>,
#   <matplotlib.patches.Wedge at 0x1bd8a0bb5c0>,
#   <matplotlib.patches.Wedge at 0x1bd8a0b9c10>,
#   <matplotlib.patches.Wedge at 0x1bd8a0b8a40>,
#   <matplotlib.patches.Wedge at 0x1bd8a0bb620>,
#   <matplotlib.patches.Wedge at 0x1bd8a0b88c0>,
#   <matplotlib.patches.Wedge at 0x1bd8a0b9370>,
#   <matplotlib.patches.Wedge at 0x1bd8a0b8410>,
#   <matplotlib.patches.Wedge at 0x1bd8a0b9b50>,
#   <matplotlib.patches.Wedge at 0x1bd8a0bbf20>,
#   <matplotlib.patches.Wedge at 0x1bd8a0b80e0>,
#   <matplotlib.patches.Wedge at 0x1bd8a0bbe90>,
#   <matplotlib.patches.Wedge at 0x1bd8a0b8d40>,
#   <matplotlib.patches.Wedge at 0x1bd8a0bb770>,
#   <matplotlib.patches.Wedge at 0x1bd8868fa40>,
#   <matplotlib.patches.Wedge at 0x1bd8868e5a0>,
#   <matplotlib.patches.Wedge at 0x1bd8868c800>,
#   <matplotlib.patches.Wedge at 0x1bd8868c890>,
#   <matplotlib.patches.Wedge at 0x1bd8868d220>,
#   <matplotlib.patches.Wedge at 0x1bd8868db50>,
#   <matplotlib.patches.Wedge at 0x1bd8868c4a0>,
#   <matplotlib.patches.Wedge at 0x1bd8868d610>,
#   <matplotlib.patches.Wedge at 0x1bd8868fb90>,
#   <matplotlib.patches.Wedge at 0x1bd8868e7b0>,
#   <matplotlib.patches.Wedge at 0x1bd8868dee0>,
#   <matplotlib.patches.Wedge at 0x1bd8868d160>,
#   <matplotlib.patches.Wedge at 0x1bd8868da60>,
#   <matplotlib.patches.Wedge at 0x1bd8868d9d0>,
#   <matplotlib.patches.Wedge at 0x1bd8a384470>,
#   <matplotlib.patches.Wedge at 0x1bd8a385160>,
#   <matplotlib.patches.Wedge at 0x1bd8a386000>,
#   <matplotlib.patches.Wedge at 0x1bd8a387200>,
#   <matplotlib.patches.Wedge at 0x1bd8a3875c0>,
#   ...],
#  [Text(1.099999366003234, 0.0011810133293006784, 'DIVYASHREE M'),
#   Text(1.0999950693921032, 0.003293525931590216, 'PRADEEP GN'),
#   Text(1.0999863370667056, 0.005482541980891168, 'NAVEENA'),
#   Text(1.0999699755297825, 0.008127295553255982, 'PREETHAAM R HOSGAVI'),
#   Text(1.099946240328782, 0.010875126968340504, 'PARAMESH'),
#   Text(1.0999203923641698, 0.013233686616009816, 'ANKIT'),
#   Text(1.0998893455662417, 0.015602163627674904, 'VINODRAJ K R'),
#   Text(1.0998534159848388, 0.017957264448727757, 'SUNANDA DESU RATHODA'),
#   Text(1.099816233100779, 0.020106054013981783, 'MAHESH PUJARI'),
#   Text(1.0997743133675064, 0.022281374666520644, 'PRASAD INGALGI'),
#   Text(1.0997260160738667, 0.02454973666460886, 'MUTTANAGOUD PATIL'),
#   Text(1.099673769626053, 0.02678806443972453, 'REVANASIDDA  NAGATHAN'),
#   Text(1.0996238712333668, 0.028763550089377247, 'SUPREETH R'),
#   Text(1.0995707957625493, 0.03072564248496633, 'SACHIN GOWDA NT'),
# ...
#   Text(-0.01450459684936409, 1.0999043670566262, 'SUDARSHAN PADANAD'),
#   Text(-0.016423759937039515, 1.0998773841249445, 'SIDRAMAPPA'),
#   Text(-0.01856274745372234, 1.0998433635781821, 'MANJU N V'),
#   Text(-0.02132677953523449, 1.0997932389656957, 'KIRAN R'),
#   Text(-0.024107588654482492, 1.0997357974392152, 'BHARGAVA K P'),
#   Text(-0.026249301421847344, 1.099686761843965, 'SHREEKALA C J'),
#   Text(-0.028201625253688665, 1.099638426180647, 'KARTHIKESH C'),
#   Text(-0.03023683434364706, 1.099584345945719, 'CHANDRASHEKAR'),
#   Text(-0.03225870140029836, 1.09952688743112, 'BEERAPPA MEDLERI'),
